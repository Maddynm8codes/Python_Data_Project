# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#               job_title_short                              job_title  \
# 568181           Data Analyst                           Data Analyst
# 301519         Data Scientist                   Intern- Data Science
# 5009            Data Engineer                          Data Engineer
# 144445         Data Scientist                    Lead Data Scientist
# 181029   Senior Data Engineer          Senior Data Engineer (Remote)
# 186115  Senior Data Scientist  【數據部 Data Team】Senior Data Scientists
# 102230           Data Analyst   Data Analyst Informatica PowerCenter
# 434382         Cloud Engineer                    Engineering Manager
# 724200  Senior Data Scientist                  Senior Data Scientist
# 354933           Data Analyst  Digital Measurement Analyst Associate
#
#                                           job_location              job_via  \
# 568181                                        Anywhere         via LinkedIn
# 301519                                       Singapore  via BeBee Singapore
# 5009                                        Camden, NJ         via LinkedIn
# 144445                           Sydney NSW, Australia      via Trabajo.org
# 181029                                        Anywhere         via LinkedIn
# 186115          Nantun District, Taichung City, Taiwan          via 104人力銀行
# 102230  Rome, Metropolitan City of Rome Capital, Italy         via Sercanto
# 434382                                         Denmark      via Trabajo.org
# 724200                                   Rockville, MD         via JobServe
# 354933                                      Boston, UK       via Learn4Good
#
#        job_schedule_type  job_work_from_home         search_location  \
# 568181         Full-time                True          United Kingdom
# 301519        Internship               False               Singapore
# 5009           Full-time               False  Florida, United States
# 144445         Full-time               False               Australia
# 181029         Full-time                True                   India
# 186115              None               False                  Taiwan
# 102230         Full-time               False                   Italy
# 434382         Full-time               False                 Denmark
# 724200         Full-time               False                 Georgia
# 354933         Full-time               False          United Kingdom
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 568181 2023-09-26 09:11:17                  False                 False
# 301519 2023-12-13 18:12:24                  False                 False
# 5009   2023-11-13 13:31:19                  False                 False
# 144445 2023-08-13 08:09:02                  False                 False
# 181029 2023-10-12 15:31:07                  False                 False
# 186115 2023-02-09 00:01:40                  False                 False
# 102230 2023-06-04 00:23:07                   True                 False
# 434382 2023-08-15 16:36:12                  False                 False
# 724200 2023-07-31 22:22:59                  False                  True
# 354933 2023-05-13 23:38:38                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 568181  United Kingdom        None              NaN              NaN
# 301519       Singapore        None              NaN              NaN
# 5009     United States        None              NaN              NaN
# 144445       Australia        None              NaN              NaN
# 181029           India        None              NaN              NaN
# 186115          Taiwan        None              NaN              NaN
# 102230           Italy        None              NaN              NaN
# 434382         Denmark        None              NaN              NaN
# 724200   United States        None              NaN              NaN
# 354933  United Kingdom        None              NaN              NaN
#
#                                   company_name  \
# 568181                 Knightsbridge Solutions
# 301519                                      HP
# 5009    Coriell Institute for Medical Research
# 144445                             TPG Telecom
# 181029                            MonetizeMore
# 186115                DECATHLON法商迪卡儂_台灣迪卡儂有限公司
# 102230                                 Beta 80
# 434382                           Lenus eHealth
# 724200                          BioSpace, Inc.
# 354933                                 myGwork
#
#                                                job_skills  \
# 568181      ['sql', 'r', 'python', 'tableau', 'power bi']
# 301519                                  ['sql', 'notion']
# 5009                                         ['r', 'sql']
# 144445  ['python', 'aws', 'azure', 'gcp', 'scikit-lear...
# 181029  ['sql', 'python', 'aws', 'azure', 'airflow', '...
# 186115                                               None
# 102230                                               None
# 434382                                     ['go', 'gdpr']
# 724200  ['sql', 'c', 'pandas', 'numpy', 'scikit-learn'...
# 354933    ['python', 'r', 'sql', 'sql server', 'tableau']
#
#                                           job_type_skills
# 568181  {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 301519      {'async': ['notion'], 'programming': ['sql']}
# 5009                        {'programming': ['r', 'sql']}
# 144445  {'cloud': ['aws', 'azure', 'gcp'], 'libraries'...
# 181029  {'cloud': ['aws', 'azure'], 'libraries': ['air...
# 186115                                               None
# 102230                                               None
# 434382     {'libraries': ['gdpr'], 'programming': ['go']}
# 724200  {'libraries': ['pandas', 'numpy', 'scikit-lear...
# 354933  {'analyst_tools': ['tableau'], 'databases': ['...

# %%
df_original = dataset['train'].to_pandas()
